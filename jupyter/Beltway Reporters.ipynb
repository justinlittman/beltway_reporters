# %% [markdown]
# # Beltway reporters
#
# Goal here is:
# 1. Get a sense of the first tweets for each user.
# 2. Using mentions show that
#    these mentions can be categorized by comparing them against lists
#    of known Twitter accounts. For now, the rough categories
#    are government, media, politicians, and reporters but these can
#    be fixed later. This can then be replicated for other groups
#    (e.g., newspaper reporters), as well as retweets and replies.
# 3. Start putting together a list of additional Twitter accounts that need
#    to be categorized.

# %% [markdown]
# ## Setup
# This creates some functions used to load the data.

# %%
import pandas as pd
import numpy as np
import json
from dateutil.parser import parse as date_parse
import gzip
import logging

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# Filepaths of the files to load.
filepaths = ['d59d27e2f2ed4778881573df2ecf2fad_001.json.gz',
            '25319652321b4bb498b250ffc53aa0f0_001.json.gz']

# Load tweets from gzipped, line-oriented JSON files, possibly transforming with provided function
# and limiting by number of tweets.
# Returns an iterator.
def tweet_iter(filepaths, limit=None, tweet_transform_func=None):
    for filepath in filepaths:
        with gzip.open(filepath) as file:
            for count, line in enumerate(file):
                if count % 50000 == 0:
                    logging.debug('Loaded %s', count)
                tweet = json.loads(line)
                if tweet_transform_func:
                    tweet_transform_ret = tweet_transform_func(tweet)
                    if isinstance(tweet_transform_ret, list):
                        for tweet in tweet_transform_ret:
                            yield tweet
                    else:
                        yield tweet_transform_ret
                else:
                    yield tweet
                if count+1 == limit:
                    break

# %% [markdown]
# ## Find first tweet for each user
# Note that by comparing the created_at date and the user_created_at date it can be determined which are new accounts and which are prolific tweeters.

# %% [markdown]
# ### Load the data and count.

# %%
# Simply the tweet on load
def tweet_transform(tweet):
    return { 
        'id': tweet['id_str'], 
        'created_at': date_parse(tweet['created_at']),
        'user_id': tweet['user']['id_str'],
        'screen_name': tweet['user']['screen_name'],
        'user_created_at': date_parse(tweet['user']['created_at']),
    }

tweet_df = pd.DataFrame(tweet_iter(filepaths, tweet_transform_func=tweet_transform))
tweet_df.count()
# Out:
# DEBUG:root:Loaded 0
# DEBUG:root:Loaded 50000
# DEBUG:root:Loaded 100000
# DEBUG:root:Loaded 150000
# DEBUG:root:Loaded 200000
# DEBUG:root:Loaded 250000
# DEBUG:root:Loaded 300000
# DEBUG:root:Loaded 350000
# DEBUG:root:Loaded 400000
# DEBUG:root:Loaded 450000
# DEBUG:root:Loaded 500000
# DEBUG:root:Loaded 550000
# DEBUG:root:Loaded 600000
# DEBUG:root:Loaded 650000
# DEBUG:root:Loaded 700000
# DEBUG:root:Loaded 750000
# DEBUG:root:Loaded 800000
# DEBUG:root:Loaded 850000
# DEBUG:root:Loaded 900000
# DEBUG:root:Loaded 950000
# DEBUG:root:Loaded 1000000
# DEBUG:root:Loaded 1050000
# DEBUG:root:Loaded 1100000
# DEBUG:root:Loaded 1150000
# DEBUG:root:Loaded 1200000
# DEBUG:root:Loaded 1250000
# DEBUG:root:Loaded 1300000
# DEBUG:root:Loaded 1350000
# DEBUG:root:Loaded 1400000
# DEBUG:root:Loaded 1450000
# DEBUG:root:Loaded 1500000
# DEBUG:root:Loaded 0
# DEBUG:root:Loaded 50000
# DEBUG:root:Loaded 100000
# DEBUG:root:Loaded 150000
# DEBUG:root:Loaded 200000
# DEBUG:root:Loaded 250000
# DEBUG:root:Loaded 300000
# DEBUG:root:Loaded 350000
# DEBUG:root:Loaded 400000
# DEBUG:root:Loaded 450000
# DEBUG:root:Loaded 500000
# DEBUG:root:Loaded 550000
# DEBUG:root:Loaded 600000
# DEBUG:root:Loaded 650000
# DEBUG:root:Loaded 700000
# DEBUG:root:Loaded 750000
# DEBUG:root:Loaded 800000
# DEBUG:root:Loaded 850000
# DEBUG:root:Loaded 900000
# DEBUG:root:Loaded 950000
# DEBUG:root:Loaded 1000000
# DEBUG:root:Loaded 1050000
# DEBUG:root:Loaded 1100000
# DEBUG:root:Loaded 1150000
# DEBUG:root:Loaded 1200000
# DEBUG:root:Loaded 1250000
# DEBUG:root:Loaded 1300000
# DEBUG:root:Loaded 1350000
# DEBUG:root:Loaded 1400000
# DEBUG:root:Loaded 1450000
# DEBUG:root:Loaded 1500000
# DEBUG:root:Loaded 1550000
# DEBUG:root:Loaded 1600000
# DEBUG:root:Loaded 1650000
# DEBUG:root:Loaded 1700000
# DEBUG:root:Loaded 1750000
# DEBUG:root:Loaded 1800000
# created_at         3364440
# id                 3364440
# screen_name        3364440
# user_created_at    3364440
# user_id            3364440
# dtype: int64

# %% [markdown]
# ### View the top of the data.

# %%
tweet_df.head()
# Out:
#                  created_at                  id  screen_name  \
# 0 2017-03-31 14:41:35+00:00  847821180832804864  A_Childers_
# 1 2017-03-31 14:15:34+00:00  847814632643473411  A_Childers_
# 2 2017-03-31 01:52:09+00:00  847627543142219776  A_Childers_
# 3 2017-03-30 23:52:23+00:00  847597404719267841  A_Childers_
# 4 2017-03-30 23:37:48+00:00  847593734896324608  A_Childers_
#
#             user_created_at     user_id
# 0 2013-08-01 21:44:28+00:00  1638925448
# 1 2013-08-01 21:44:28+00:00  1638925448
# 2 2013-08-01 21:44:28+00:00  1638925448
# 3 2013-08-01 21:44:28+00:00  1638925448
# 4 2013-08-01 21:44:28+00:00  1638925448

# %% [markdown]
# ### First tweet for each user
# created_at is the date of the first tweet in the dataset for the user. This can be compared
# against user_created_at, the date the user account was created.

# %%
tweet_df.loc[tweet_df.groupby('user_id')['created_at'].idxmin()].sort_values('created_at', ascending=False).head(20)
# Out:
#                        created_at                  id      screen_name  \
# 946753  2017-03-31 17:07:58+00:00  847858018809237504         sklee_ca
# 745318  2017-03-27 13:25:07+00:00  846352383609356288       emmaroller
# 959935  2017-03-17 17:27:58+00:00  842789621314588673  RebeccaEHoffman
# 942211  2017-03-15 14:16:31+00:00  842016664237559809    ErinMcManus15
# 2530157 2017-03-10 16:33:43+00:00  840239253745471489          EvanMcS
# 810658  2017-03-10 13:43:41+00:00  840196461472174081        CahnEmily
# 1906009 2017-03-08 20:33:21+00:00  839574782341414912   LaurenFCarroll
# 2552103 2017-03-07 16:38:59+00:00  839153415515168768       ericgeller
# 780962  2017-03-03 22:00:52+00:00  837784869958737920      HotlineJosh
# 2200367 2017-03-02 16:35:58+00:00  837340716560953344     chrisgeidner
# 27391   2017-02-28 19:00:31+00:00  836652316191244288   BeddingfieldMJ
# 1193879 2017-02-16 19:05:49+00:00  832304997639581698       AaronMehta
# 933507  2017-02-15 14:48:35+00:00  831877875762618368     AlexParkerDC
# 1823080 2017-02-12 15:54:14+00:00  830807232224833536    maria_e_recio
# 2113085 2017-02-09 21:56:58+00:00  829811353686831105       daveweigel
# 511794  2017-02-08 21:50:54+00:00  829447440034066432     OSHAReporter
# 3041588 2017-02-08 13:44:00+00:00  829324908438102016          sdonnan
# 15101   2017-02-03 20:46:05+00:00  827619189259194368     brianbeutler
# 297726  2017-02-03 01:33:02+00:00  827329014612291585        JSwiftTWS
# 1514745 2017-02-02 15:57:24+00:00  827184151430365184     ryanbeckwith
#
#                   user_created_at             user_id
# 946753  2009-09-23 17:09:53+00:00            76696176
# 745318  2009-08-18 19:10:55+00:00            66768858
# 959935  2017-03-17 17:18:52+00:00  842787331224584192
# 942211  2017-02-15 21:03:24+00:00  831972200014045191
# 2530157 2009-02-06 23:09:59+00:00            20281013
# 810658  2009-01-10 03:19:50+00:00            18825339
# 1906009 2009-04-10 06:29:32+00:00            30176025
# 2552103 2007-04-08 20:27:11+00:00             3817401
# 780962  2009-02-22 23:45:46+00:00            21612122
# 2200367 2009-03-05 06:48:00+00:00            22891564
# 27391   2017-02-28 18:23:37+00:00  836643030161625089
# 1193879 2010-01-08 15:53:25+00:00           103016675
# 933507  2011-03-31 20:53:10+00:00           275207082
# 1823080 2012-01-06 22:22:40+00:00           456994513
# 2113085 2008-02-15 17:58:23+00:00            13524182
# 511794  2017-02-03 19:50:14+00:00  827605131109793792
# 3041588 2009-02-24 23:10:17+00:00            21810329
# 15101   2009-02-23 21:31:16+00:00            21696279
# 297726  2008-06-17 15:19:03+00:00            15146659
# 1514745 2008-09-25 22:43:36+00:00            16459325

# %% [markdown]
# ## Top mentions
# Determine who is being mentioned and attempt to characterize.

# %%
# Simply the tweet on load
def mention_transform(tweet):
    mentions = []
    for mention in tweet.get('entities', {}).get('user_mentions', []):
        mentions.append({
            'id': tweet['id_str'],
            'user_id': tweet['user']['id_str'],
            'screen_name': tweet['user']['screen_name'],
            'mention_user_id': mention['id_str'],
            'mention_screen_name': mention['screen_name'],
            'created_at': date_parse(tweet['created_at'])
        })
    return mentions

mention_df = pd.DataFrame(tweet_iter(filepaths, tweet_transform_func=mention_transform))
# Out:
# DEBUG:root:Loaded 0
# DEBUG:root:Loaded 50000
# DEBUG:root:Loaded 100000
# DEBUG:root:Loaded 150000
# DEBUG:root:Loaded 200000
# DEBUG:root:Loaded 250000
# DEBUG:root:Loaded 300000
# DEBUG:root:Loaded 350000
# DEBUG:root:Loaded 400000
# DEBUG:root:Loaded 450000
# DEBUG:root:Loaded 500000
# DEBUG:root:Loaded 550000
# DEBUG:root:Loaded 600000
# DEBUG:root:Loaded 650000
# DEBUG:root:Loaded 700000
# DEBUG:root:Loaded 750000
# DEBUG:root:Loaded 800000
# DEBUG:root:Loaded 850000
# DEBUG:root:Loaded 900000
# DEBUG:root:Loaded 950000
# DEBUG:root:Loaded 1000000
# DEBUG:root:Loaded 1050000
# DEBUG:root:Loaded 1100000
# DEBUG:root:Loaded 1150000
# DEBUG:root:Loaded 1200000
# DEBUG:root:Loaded 1250000
# DEBUG:root:Loaded 1300000
# DEBUG:root:Loaded 1350000
# DEBUG:root:Loaded 1400000
# DEBUG:root:Loaded 1450000
# DEBUG:root:Loaded 1500000
# DEBUG:root:Loaded 0
# DEBUG:root:Loaded 50000
# DEBUG:root:Loaded 100000
# DEBUG:root:Loaded 150000
# DEBUG:root:Loaded 200000
# DEBUG:root:Loaded 250000
# DEBUG:root:Loaded 300000
# DEBUG:root:Loaded 350000
# DEBUG:root:Loaded 400000
# DEBUG:root:Loaded 450000
# DEBUG:root:Loaded 500000
# DEBUG:root:Loaded 550000
# DEBUG:root:Loaded 600000
# DEBUG:root:Loaded 650000
# DEBUG:root:Loaded 700000
# DEBUG:root:Loaded 750000
# DEBUG:root:Loaded 800000
# DEBUG:root:Loaded 850000
# DEBUG:root:Loaded 900000
# DEBUG:root:Loaded 950000
# DEBUG:root:Loaded 1000000
# DEBUG:root:Loaded 1050000
# DEBUG:root:Loaded 1100000
# DEBUG:root:Loaded 1150000
# DEBUG:root:Loaded 1200000
# DEBUG:root:Loaded 1250000
# DEBUG:root:Loaded 1300000
# DEBUG:root:Loaded 1350000
# DEBUG:root:Loaded 1400000
# DEBUG:root:Loaded 1450000
# DEBUG:root:Loaded 1500000
# DEBUG:root:Loaded 1550000
# DEBUG:root:Loaded 1600000
# DEBUG:root:Loaded 1650000
# DEBUG:root:Loaded 1700000
# DEBUG:root:Loaded 1750000
# DEBUG:root:Loaded 1800000

# %% [markdown]
# ### Number of mentions found in the dataset

# %%
mention_df.count()
# Out:
# created_at             3029170
# id                     3029170
# mention_screen_name    3029170
# mention_user_id        3029170
# screen_name            3029170
# user_id                3029170
# dtype: int64

# %% [markdown]
# ### The mention data
# Each mention consists of the tweet id, the screen name and user id that is mentioned,
# and the screen_name and user_id that is mentioning.

# %%
mention_df.head()
# Out:
#                  created_at                  id mention_screen_name  \
# 0 2017-03-31 14:41:35+00:00  847821180832804864          paulconndc
# 1 2017-03-31 14:41:35+00:00  847821180832804864        Pat_Ambrosio
# 2 2017-03-31 14:15:34+00:00  847814632643473411              azevin
# 3 2017-03-31 01:52:09+00:00  847627543142219776       davidbschultz
# 4 2017-03-30 23:52:23+00:00  847597404719267841       davidbschultz
#
#   mention_user_id  screen_name     user_id
# 0        64502388  A_Childers_  1638925448
# 1      2497185313  A_Childers_  1638925448
# 2        14744078  A_Childers_  1638925448
# 3        53739928  A_Childers_  1638925448
# 4        53739928  A_Childers_  1638925448

# %%
# From the mentions, extract map of user ids to screen names
user_id_lookup_df = mention_df.loc[mention_df.groupby('mention_user_id')['created_at'].idxmax()].ix[:,['mention_user_id', 'mention_screen_name']]
user_id_lookup_df.count()
# Out:
# mention_user_id        205234
# mention_screen_name    205234
# dtype: int64

# %%
user_id_lookup_df.head()
# Out:
#         mention_user_id mention_screen_name
# 1867558       100000880        rifatbasaran
# 562407       1000010898         RoyScranton
# 1036649       100002112      whyyradiotimes
# 204724       1000030188          jessieb747
# 686671        100003141          NCCDtweets

# %%
# Group by user_id
# This count should match the user_id map count
mention_summary_user_id_df = pd.DataFrame(mention_df.groupby('mention_user_id').size().reset_index(name='mention_screen_name_count'))
mention_summary_user_id_df.count()
# Out:
# mention_user_id              205234
# mention_screen_name_count    205234
# dtype: int64

# %%
mention_summary_user_id_df.head()
# Out:
#   mention_user_id  mention_screen_name_count
# 0       100000880                          1
# 1      1000010898                         24
# 2       100002112                         69
# 3      1000030188                         10
# 4       100003141                          6

# %%
# Join with user id map
mention_summary_df = pd.merge(mention_summary_user_id_df, user_id_lookup_df, on='mention_user_id')
mention_summary_df.count()
# Out:
# mention_user_id              205234
# mention_screen_name_count    205234
# mention_screen_name          205234
# dtype: int64

# %%
mention_summary_df.head()
# Out:
#   mention_user_id  mention_screen_name_count mention_screen_name
# 0       100000880                          1        rifatbasaran
# 1      1000010898                         24         RoyScranton
# 2       100002112                         69      whyyradiotimes
# 3      1000030188                         10          jessieb747
# 4       100003141                          6          NCCDtweets

# %% [markdown]
# ### Load known Twitter accounts

# %%
def seed_iter(filepath):
    with open(filepath) as file:
        for line in file:
            screen_name, user_id = line.split(',')
            yield {'screen_name': screen_name, 'user_id': user_id[:-1]}

def load_seed_df(filepath, seed_type):
    df = pd.DataFrame(seed_iter(filepath))
    df['screen_name_lower'] = df.screen_name.apply(str.lower)
    df['type'] = seed_type
    return df

# %%
federal_agencies_df = load_seed_df('federal_agencies.csv', 'government')
federal_agencies_df.count()
# Out:
# screen_name          2968
# user_id              2968
# screen_name_lower    2968
# type                 2968
# dtype: int64

# %%
news_outlets_df = load_seed_df('news_outlets.csv', 'media')
news_outlets_df.count()
# Out:
# screen_name          92
# user_id              92
# screen_name_lower    92
# type                 92
# dtype: int64

# %%
newspaper_reporters_df = load_seed_df('newspaper_reporters.csv', 'reporters')
newspaper_reporters_df.count()
# Out:
# screen_name          790
# user_id              790
# screen_name_lower    790
# type                 790
# dtype: int64

# %%
periodical_reporters_df = load_seed_df('periodical_reporters.csv', 'reporters')
periodical_reporters_df.count()
# Out:
# screen_name          677
# user_id              677
# screen_name_lower    677
# type                 677
# dtype: int64

# %%
administration_officials_df = load_seed_df('administration_officials.csv', 'politicians')
administration_officials_df.count()
# Out:
# screen_name          63
# user_id              63
# screen_name_lower    63
# type                 63
# dtype: int64

# %%
cabinet_df = load_seed_df('cabinet.csv', 'politicians')
cabinet_df.count()
# Out:
# screen_name          12
# user_id              12
# screen_name_lower    12
# type                 12
# dtype: int64

# %%
representatives_df = load_seed_df('representatives.csv', 'politicians')
representatives_df.count()
# Out:
# screen_name          431
# user_id              431
# screen_name_lower    431
# type                 431
# dtype: int64

# %%
senators_df = load_seed_df('senators.csv', 'politicians')
senators_df.count()
# Out:
# screen_name          100
# user_id              100
# screen_name_lower    100
# type                 100
# dtype: int64

# %%
media_df = load_seed_df('media.csv', 'media')
media_df.count()
# Out:
# screen_name          5997
# user_id              5997
# screen_name_lower    5997
# type                 5997
# dtype: int64

# %%
# Order is deliberate here, since will be deduplicating.
screen_name_lookup_df = newspaper_reporters_df.append([administration_officials_df,
                                      news_outlets_df,
                                      periodical_reporters_df,
                                      cabinet_df,
                                      representatives_df,
                                      senators_df,
                                      media_df,
                                      federal_agencies_df], ignore_index=True).drop_duplicates(subset='screen_name_lower')
screen_name_lookup_df.count()
# Out:
# screen_name          10932
# user_id              10932
# screen_name_lower    10932
# type                 10932
# dtype: int64

# %% [markdown]
# ### Join the mentions and the known Twitter accounts

# %%
mention_join_df = pd.merge(mention_summary_df, screen_name_lookup_df, how='left', left_on='mention_user_id', right_on='user_id')
mention_join_df['type'].fillna('unknown', inplace=True)
mention_join_df.head()
# Out:
#   mention_user_id  mention_screen_name_count mention_screen_name screen_name  \
# 0       100000880                          1        rifatbasaran         NaN
# 1      1000010898                         24         RoyScranton         NaN
# 2       100002112                         69      whyyradiotimes         NaN
# 3      1000030188                         10          jessieb747         NaN
# 4       100003141                          6          NCCDtweets         NaN
#
#   user_id screen_name_lower     type
# 0     NaN               NaN  unknown
# 1     NaN               NaN  unknown
# 2     NaN               NaN  unknown
# 3     NaN               NaN  unknown
# 4     NaN               NaN  unknown

# %% [markdown]
# ### Top (by mention count) accounts that are matched against known Twitter accounts

# %%
top_known_mentions_df = mention_join_df[pd.notnull(mention_join_df.screen_name)].sort_values('mention_screen_name_count', ascending=False)
top_known_mentions_df[['mention_screen_name', 'user_id', 'mention_screen_name_count', 'type']].head()
# Out:
#        mention_screen_name             user_id  mention_screen_name_count  \
# 90027      realDonaldTrump            25073877                      33899
# 160709                  AP            51241574                      29688
# 117042                 WSJ             3108351                      18616
# 193399               POTUS  822215679726100480                      16846
# 32881             USATODAY            15754281                      15634
#
#                type
# 90027   politicians
# 160709        media
# 117042        media
# 193399  politicians
# 32881         media

# %% [markdown]
# ### Number of matched accounts
# mention_screen_name is the number of unique mentioned accounts. screen_name is the
# number of matched unique accounts.

# %%
mention_join_df.count()
# Out:
# mention_user_id              205234
# mention_screen_name_count    205234
# mention_screen_name          205234
# screen_name                    4443
# user_id                        4443
# screen_name_lower              4443
# type                         205234
# dtype: int64

# %% [markdown]
# ### Top accounts by mentions
# Unknown for type indicates that it is not matched with an known Twitter account.

# %%
top_mentions_df = mention_join_df.sort_values('mention_screen_name_count', ascending=False)
top_mentions_df[['mention_screen_name', 'user_id', 'mention_screen_name_count', 'type']].head(50)
# Out:
#        mention_screen_name             user_id  mention_screen_name_count  \
# 90027      realDonaldTrump            25073877                      33899
# 160709                  AP            51241574                      29688
# 78299                CQnow                 NaN                      20586
# 117042                 WSJ             3108351                      18616
# 193399               POTUS  822215679726100480                      16846
# 32881             USATODAY            15754281                      15634
# 16470       HillaryClinton                 NaN                      15628
# 201494            politico             9300262                      15310
# 34333             rollcall            15922214                      15118
# 39399              Reuters             1652541                      14000
# 87570       washingtonpost             2467791                      12726
# 191342             nytimes              807095                      12493
# 128979            business                 NaN                      12370
# 28160        educationweek                 NaN                      10667
# 151619        BloombergBNA                 NaN                      10124
# 192800            PressSec  818927131883356161                       9124
# 146286         AP_Politics           426802833                       9018
# 55088           dcexaminer                 NaN                       8924
# 189355        EEPublishing                 NaN                       7271
# 24493            WashTimes            14662354                       7070
# 201556           maggieNYT                 NaN                       6848
# 56711              thehill             1917731                       6646
# 166856           bpolitics                 NaN                       5839
# 128700        BloombergLaw                 NaN                       5744
# 54787          SpeakerRyan            18916432                       5497
# 24124                  EPA            14615871                       5131
# 69144        BernieSanders                 NaN                       4863
# 64876          POLITICOPro                 NaN                       4840
# 17025           daveweigel            13524182                       4590
# 19256      nielslesniewski           140286364                       4366
# 140764           MEPFuller           398088661                       4214
# 202936         BostonGlobe            95431448                       4164
# 185503                 CNN              759251                       4146
# 77671              tedcruz                 NaN                       4114
# 67154          ZekeJMiller            21316253                       4049
# 170229        PhilipRucker                 NaN                       3928
# 56785          seungminkim            19186003                       3896
# 142498           burgessev           407013776                       3823
# 69700         BresPolitico           217550862                       3814
# 37684          WSJPolitics                 NaN                       3768
# 66912          JakeSherman            21252618                       3767
# 152778       StevenTDennis            46557945                       3745
# 200157       EENewsUpdates                 NaN                       3707
# 192098         BarackObama                 NaN                       3666
# 23479           jaketapper                 NaN                       3646
# 56290          GlennThrush            19107878                       3508
# 136756                 AFP           380648579                       3472
# 28640      nationaljournal                 NaN                       3416
# 192792                  VP  818910970567344128                       3395
# 32820           marcorubio                 NaN                       3366
#
#                type
# 90027   politicians
# 160709        media
# 78299       unknown
# 117042        media
# 193399  politicians
# 32881         media
# 16470       unknown
# 201494        media
# 34333         media
# 39399         media
# 87570         media
# 191342        media
# 128979      unknown
# 28160       unknown
# 151619      unknown
# 192800  politicians
# 146286        media
# 55088       unknown
# 189355      unknown
# 24493         media
# 201556      unknown
# 56711         media
# 166856      unknown
# 128700      unknown
# 54787   politicians
# 24124    government
# 69144       unknown
# 64876       unknown
# 17025     reporters
# 19256     reporters
# 140764    reporters
# 202936        media
# 185503        media
# 77671       unknown
# 67154     reporters
# 170229      unknown
# 56785     reporters
# 142498    reporters
# 69700     reporters
# 37684       unknown
# 66912     reporters
# 152778    reporters
# 200157      unknown
# 192098      unknown
# 23479       unknown
# 56290     reporters
# 136756        media
# 28640       unknown
# 192792  politicians
# 32820       unknown

# %% [markdown]
# ### Mentions by account type

# %%
mention_join_df.groupby('type').sum()
# Out:
#              mention_screen_name_count
# type
# government                       60820
# media                           236317
# politicians                     164299
# reporters                       563123
# unknown                        2004611

# %% [markdown]
# ### Top (by mentions) accounts that are not known.
# These are the accounts that we will want to categorize.

# %%
top_not_known_mention_df = mention_join_df[mention_join_df.type == 'unknown'].sort_values('mention_screen_name_count', ascending=False)
top_not_known_mention_df[['mention_screen_name', 'mention_screen_name_count']].head(100)
# Out:
#        mention_screen_name  mention_screen_name_count
# 78299                CQnow                      20586
# 16470       HillaryClinton                      15628
# 128979            business                      12370
# 28160        educationweek                      10667
# 151619        BloombergBNA                      10124
# 55088           dcexaminer                       8924
# 189355        EEPublishing                       7271
# 201556           maggieNYT                       6848
# 166856           bpolitics                       5839
# 128700        BloombergLaw                       5744
# 69144        BernieSanders                       4863
# 64876          POLITICOPro                       4840
# 77671              tedcruz                       4114
# 170229        PhilipRucker                       3928
# 37684          WSJPolitics                       3768
# 200157       EENewsUpdates                       3707
# 192098         BarackObama                       3666
# 23479           jaketapper                       3646
# 28640      nationaljournal                       3416
# 32820           marcorubio                       3366
# 52597             FERNnews                       3316
# 28302                Slate                       3290
# 55024                   FT                       3207
# 27101       MorningConsult                       3177
# 102298                 RNS                       3157
# 55676              Publici                       3051
# 175051          newsfromIN                       2985
# 24689       Militarydotcom                       2938
# 44721       blakehounshell                       2853
# 44388              Nextgov                       2809
# ...                    ...                        ...
# 46229          McClatchyDC                       1752
# 186972      SpeakerBoehner                       1723
# 24042           ProPublica                       1715
# 70240           Bencjacobs                       1706
# 29338       capitalweather                       1694
# 12443         SenateMajLdr                       1681
# 11991            chronicle                       1664
# 21284           elisefoley                       1651
# 80404            voxdotcom                       1646
# 176035              usnews                       1600
# 72989        davelevinthal                       1599
# 37899              WSJecon                       1571
# 37173               jbarro                       1552
# 54939                wmata                       1537
# 21907           DefenseOne                       1517
# 44966             timkaine                       1488
# 159748           chucktodd                       1477
# 22060            postlocal                       1477
# 159438            Pontifex                       1452
# 139905           Nationals                       1450
# 21253         ron_fournier                       1435
# 35120          BenjySarlin                       1435
# 182013           YahooNews                       1423
# 154490              lrozen                       1409
# 134345          sangerkatz                       1408
# 202716               pbump                       1404
# 37659             vicenews                       1399
# 122862        kylegriffin1                       1392
# 44591               FCWnow                       1387
# 139540          AmyAHarder                       1385
#
# [100 rows x 2 columns]
