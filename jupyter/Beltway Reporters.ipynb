# %% [markdown]
# # Beltway reporters
#
# Goal here is:
# 1. Get a sense of the first tweets for each user.
# 2. Using mentions by the periodical reporters as an example, show that
#    these mentions can be categorized by comparing them against lists
#    of known Twitter accounts. For now, the rough categories
#    are government, media, politicians, and reporters but these can
#    be fixed later. This can then be replicated for other groups
#    (e.g., newspaper reporters), as well as retweets and replies.
# 3. Start putting together a list of additional Twitter accounts that need
#    to be categorized.

# %% [markdown]
# ## Setup
# This creates some functions used to load the data.

# %%
import pandas as pd
import numpy as np
import json
from dateutil.parser import parse as date_parse

# Load tweets from line-oriented JSON file, possibly transforming with provided function
# and limiting by number of tweets.
# Returns an iterator.
def tweet_iter(filepath, limit=None, tweet_transform_func=None):
    with open(filepath) as file:
        for count, line in enumerate(file):
            tweet = json.loads(line)
            if tweet_transform_func:
                tweet_transform_ret = tweet_transform_func(tweet)
                if isinstance(tweet_transform_ret, list):
                    for tweet in tweet_transform_ret:
                        yield tweet
                else:
                    yield tweet_transform_ret
            else:
                yield tweet
            if count+1 == limit:
                break

# %% [markdown]
# ## Find first tweet for each user
# Note that by comparing the created_at date and the user_created_at date it can be determined which are new accounts and which are prolific tweeters.
#
# __Note that this is using data collected from the periodical press.__

# %% [markdown]
# ### Load the data and count.

# %%
# Simply the tweet on load
def tweet_transform(tweet):
    return { 
        'id': tweet['id_str'], 
        'created_at': date_parse(tweet['created_at']),
        'user_id': tweet['user']['id_str'],
        'screen_name': tweet['user']['screen_name'],
        'user_created_at': date_parse(tweet['user']['created_at']),
    }

tweet_df = pd.DataFrame(tweet_iter('034f608f30bd4800a1c448b490125b1d_001.json', tweet_transform_func=tweet_transform))
tweet_df.count()
# Out:
# created_at         515215
# id                 515215
# screen_name        515215
# user_created_at    515215
# user_id            515215
# dtype: int64

# %% [markdown]
# ### View the top of the data.

# %%
tweet_df.head()
# Out:
#                  created_at                  id screen_name  \
# 0 2017-03-09 17:30:14+00:00  839891087095447552    Bruninga
# 1 2017-03-09 17:25:19+00:00  839889849419186176    Bruninga
# 2 2017-03-08 18:05:52+00:00  839537669067718659    Bruninga
# 3 2017-03-07 02:58:35+00:00  838946955292192768    Bruninga
# 4 2017-03-01 19:27:43+00:00  837021552428343296    Bruninga
#
#             user_created_at    user_id
# 0 2010-01-21 19:04:23+00:00  107170206
# 1 2010-01-21 19:04:23+00:00  107170206
# 2 2010-01-21 19:04:23+00:00  107170206
# 3 2010-01-21 19:04:23+00:00  107170206
# 4 2010-01-21 19:04:23+00:00  107170206

# %% [markdown]
# ### First tweet for each user
# created_at is the date of the first tweet in the dataset for the user. This can be compared
# against user_created_at, the date the user account was created.

# %%
tweet_df.loc[tweet_df.groupby('user_id')['created_at'].idxmin()].sort_values('created_at', ascending=False).head(20)
# Out:
#                       created_at                  id     screen_name  \
# 18253  2017-02-28 19:00:31+00:00  836652316191244288  BeddingfieldMJ
# 502656 2017-02-08 21:50:54+00:00  829447440034066432    OSHAReporter
# 5963   2017-02-03 20:46:05+00:00  827619189259194368    brianbeutler
# 288588 2017-02-03 01:33:02+00:00  827329014612291585       JSwiftTWS
# 372117 2017-02-01 15:30:41+00:00  826815038728052736        ToporHCF
# 126979 2017-01-22 14:19:59+00:00  823173369281544192          edroso
# 214337 2017-01-21 20:44:35+00:00  822907768801816578      MikeMadden
# 77791  2016-12-21 00:51:22+00:00  811373460857454592    GrahamDavidA
# 144540 2016-12-20 17:55:31+00:00  811268809021657089    DefenseBaron
# 28914  2016-12-20 05:48:07+00:00  811085752041926656   andrewperezdc
# 211096 2016-12-03 17:27:45+00:00  805101226132197378          mjs_DC
# 342748 2016-11-14 23:06:42+00:00  798301159526170624      JamilSmith
# 32143  2016-11-07 20:39:46+00:00  795727464249131008      amir_anasr
# 91816  2016-11-06 15:57:46+00:00  795294109124665345           fordm
# 237942 2016-11-03 18:07:43+00:00  794239649602473986   McCormackJohn
# 9197   2016-10-25 21:32:13+00:00  791029623832412160         brfreed
# 398123 2016-10-22 20:58:15+00:00  789933913200361477       SpyTalker
# 390374 2016-10-22 03:09:24+00:00  789664927925604352     StuPolitics
# 502557 2016-10-12 16:24:33+00:00  786241156095107076        palbergo
# 201435 2016-10-07 17:35:27+00:00  784447059625701376    mollymotoole
#
#                  user_created_at             user_id
# 18253  2017-02-28 18:23:37+00:00  836643030161625089
# 502656 2017-02-03 19:50:14+00:00  827605131109793792
# 5963   2009-02-23 21:31:16+00:00            21696279
# 288588 2008-06-17 15:19:03+00:00            15146659
# 372117 2017-02-01 15:05:54+00:00  826808800921403393
# 126979 2008-08-05 01:29:22+00:00            15730608
# 214337 2008-01-11 22:43:03+00:00            12134692
# 77791  2009-06-13 20:18:33+00:00            46955476
# 144540 2009-01-15 20:59:03+00:00            19038768
# 28914  2009-02-22 17:16:51+00:00            21579498
# 211096 2009-11-07 16:18:03+00:00            88215673
# 342748 2009-06-10 20:18:48+00:00            46213956
# 32143  2012-02-16 04:45:33+00:00           493756786
# 91816  2009-03-25 18:39:00+00:00            26559241
# 237942 2009-03-30 17:47:36+00:00            27689907
# 9197   2008-03-24 14:49:27+00:00            14207809
# 398123 2009-04-02 16:18:49+00:00            28366439
# 390374 2011-02-11 20:09:49+00:00           250784170
# 502557 2010-02-25 17:14:47+00:00           117467779
# 201435 2010-01-29 01:25:29+00:00           109431937

# %% [markdown]
# ## Top mentions
# Determine who is being mentioned and attempt to characterize.
#
# __Note that this is using data collected from the periodical press.__

# %%
# Simply the tweet on load
def mention_transform(tweet):
    mentions = []
    for mention in tweet.get('entities', {}).get('user_mentions', []):
        mentions.append({
            'id': tweet['id_str'],
            'user_id': tweet['user']['id_str'],
            'screen_name': tweet['user']['screen_name'],
            'mention_user_id': mention['id_str'],
            'mention_screen_name': mention['screen_name']
        })
    return mentions

mention_df = pd.DataFrame(tweet_iter('034f608f30bd4800a1c448b490125b1d_001.json', tweet_transform_func=mention_transform))

# %% [markdown]
# ### Number of mentions found in the dataset

# %%
mention_df.count()
# Out:
# id                     466766
# mention_screen_name    466766
# mention_user_id        466766
# screen_name            466766
# user_id                466766
# dtype: int64

# %% [markdown]
# ### The mention data
# Each mention consists of the tweet id, the screen name and user id that is mentioned,
# and the screen_name and user_id that is mentioning.

# %%
mention_df.head()
# Out:
#                    id mention_screen_name mention_user_id screen_name  \
# 0  839891087095447552     BBNAEnvironment        41847726    Bruninga
# 1  839891087095447552        BloombergBNA       459277523    Bruninga
# 2  839889849419186176                 EPA        14615871    Bruninga
# 3  839889849419186176     BBNAEnvironment        41847726    Bruninga
# 4  839889849419186176        BloombergBNA       459277523    Bruninga
#
#      user_id
# 0  107170206
# 1  107170206
# 2  107170206
# 3  107170206
# 4  107170206

# %% [markdown]
# ### Top mentioned accounts

# %%
mention_summary_df = pd.DataFrame(mention_df.groupby('mention_screen_name').size().reset_index(name='mention_screen_name_count'))
mention_summary_df['mention_screen_name_lower'] = mention_summary_df.mention_screen_name.apply(str.lower)
mention_summary_df.sort_values('mention_screen_name_count', ascending=False).head(50)
# Out:
#       mention_screen_name  mention_screen_name_count mention_screen_name_lower
# 4569         BloombergBNA                       7055              bloombergbna
# 61138     realDonaldTrump                       3367           realdonaldtrump
# 4579         BloombergLaw                       2710              bloomberglaw
# 36690           WashBlade                       2300                 washblade
# 19206     KimberlyRobinsn                       2254           kimberlyrobinsn
# 23462      MorningConsult                       2221            morningconsult
# 12295       ForeignPolicy                       2144             foreignpolicy
# 26187               POTUS                       1916                     potus
# 10450                 EPA                       1847                       epa
# 31756               Slate                       1820                     slate
# 58984             nytimes                       1779                   nytimes
# 42006            business                       1562                  business
# 43103           chronicle                       1431                 chronicle
# 865                    AP                       1386                        ap
# 67198      washingtonpost                       1360            washingtonpost
# 2701       AnthonyAdragna                       1197            anthonyadragna
# 14580      HillaryClinton                       1163            hillaryclinton
# 9394           DefenseOne                        996                defenseone
# 11630              FCWnow                        992                    fcwnow
# 36479                 WSJ                        948                       wsj
# 38410           agripulse                        880                 agripulse
# 24741          NatureNews                        868                naturenews
# 27373            PressSec                        865                  presssec
# 33679         TheAtlantic                        837               theatlantic
# 44574          daveweigel                        831                daveweigel
# 60345            politico                        826                  politico
# 16789       JeffreyToobin                        782             jeffreytoobin
# 67266                 wcp                        780                       wcp
# 65397             thehill                        776                   thehill
# 51650            jmartNYT                        716                  jmartnyt
# 58102     nationaljournal                        687           nationaljournal
# 3360      BBNAEnvironment                        650           bbnaenvironment
# 67196       washingtonian                        650             washingtonian
# 1112          A_Childers_                        645               a_childers_
# 5876                  CNN                        631                       cnn
# 12725           GOVERNING                        626                 governing
# 41546           bpolitics                        626                 bpolitics
# 1795          Alex_Roarty                        606               alex_roarty
# 235                 47abc                        601                     47abc
# 55397           maggieNYT                        596                 maggienyt
# 23802                NASA                        593                      nasa
# 26424        Pat_Ambrosio                        581              pat_ambrosio
# 24927           NewYorker                        577                 newyorker
# 25183          NinaEaston                        569                ninaeaston
# 59430            palbergo                        568                  palbergo
# 36709           WashTimes                        561                 washtimes
# 28974             Reuters                        556                   reuters
# 24985            Newsweek                        556                  newsweek
# 21594       MarcusReports                        555             marcusreports
# 4292            BigLawBiz                        545                 biglawbiz

# %% [markdown]
# ### Load known Twitter accounts

# %%
def seed_iter(filepath):
    with open(filepath) as file:
        for line in file:
            screen_name, user_id = line.split(',')
            yield {'screen_name': screen_name, 'user_id': user_id[:-1]}

def load_seed_df(filepath, seed_type):
    df = pd.DataFrame(seed_iter(filepath))
    df['screen_name_lower'] = df.screen_name.apply(str.lower)
    df['type'] = seed_type
    return df

# %%
federal_agencies_df = load_seed_df('federal_agencies.csv', 'government')
federal_agencies_df.count()
# Out:
# screen_name          2968
# user_id              2968
# screen_name_lower    2968
# type                 2968
# dtype: int64

# %%
news_outlets_df = load_seed_df('news_outlets.csv', 'media')
news_outlets_df.count()
# Out:
# screen_name          92
# user_id              92
# screen_name_lower    92
# type                 92
# dtype: int64

# %%
newspaper_reporters_df = load_seed_df('newspaper_reporters.csv', 'reporters')
newspaper_reporters_df.count()
# Out:
# screen_name          795
# user_id              795
# screen_name_lower    795
# type                 795
# dtype: int64

# %%
periodical_reporters_df = load_seed_df('periodical_reporters.csv', 'reporters')
periodical_reporters_df.count()
# Out:
# screen_name          256
# user_id              256
# screen_name_lower    256
# type                 256
# dtype: int64

# %%
administration_officials_df = load_seed_df('administration_officials.csv', 'politicians')
administration_officials_df.count()
# Out:
# screen_name          63
# user_id              63
# screen_name_lower    63
# type                 63
# dtype: int64

# %%
cabinet_df = load_seed_df('cabinet.csv', 'politicians')
cabinet_df.count()
# Out:
# screen_name          12
# user_id              12
# screen_name_lower    12
# type                 12
# dtype: int64

# %%
representatives_df = load_seed_df('representatives.csv', 'politicians')
representatives_df.count()
# Out:
# screen_name          431
# user_id              431
# screen_name_lower    431
# type                 431
# dtype: int64

# %%
senators_df = load_seed_df('senators.csv', 'politicians')
senators_df.count()
# Out:
# screen_name          100
# user_id              100
# screen_name_lower    100
# type                 100
# dtype: int64

# %%
media_df = load_seed_df('media.csv', 'media')
media_df.count()
# Out:
# screen_name          5997
# user_id              5997
# screen_name_lower    5997
# type                 5997
# dtype: int64

# %%
# Order is deliberate here, since will be deduplicating.
screen_name_lookup_df = newspaper_reporters_df.append([administration_officials_df,
                                      news_outlets_df,
                                      periodical_reporters_df,
                                      cabinet_df,
                                      representatives_df,
                                      senators_df,
                                      media_df,
                                      federal_agencies_df], ignore_index=True).drop_duplicates(subset='screen_name_lower')
screen_name_lookup_df.count()
# Out:
# screen_name          10524
# user_id              10524
# screen_name_lower    10524
# type                 10524
# dtype: int64

# %% [markdown]
# ### Join the mentions and the known Twitter accounts

# %%
mention_join_df = pd.merge(mention_summary_df, screen_name_lookup_df, how='left', left_on='mention_screen_name_lower', right_on='screen_name_lower')
mention_join_df['type'].fillna('unknown', inplace=True)

# %% [markdown]
# ### Top (by mention count) accounts that are matched against known Twitter accounts

# %%
mention_join_df[pd.notnull(mention_join_df.screen_name)].sort_values('mention_screen_name_count', ascending=False).head()
# Out:
#       mention_screen_name  mention_screen_name_count  \
# 61138     realDonaldTrump                       3367
# 19206     KimberlyRobinsn                       2254
# 26187               POTUS                       1916
# 10450                 EPA                       1847
# 58984             nytimes                       1779
#
#       mention_screen_name_lower      screen_name             user_id  \
# 61138           realdonaldtrump  realDonaldTrump            25073877
# 19206           kimberlyrobinsn  KimberlyRobinsn           906734342
# 26187                     potus            POTUS  822215679726100480
# 10450                       epa              EPA            14615871
# 58984                   nytimes          nytimes              807095
#
#       screen_name_lower         type
# 61138   realdonaldtrump  politicians
# 19206   kimberlyrobinsn    reporters
# 26187             potus  politicians
# 10450               epa   government
# 58984           nytimes        media

# %% [markdown]
# ### Number of matched accounts
# mention_screen_name is the number of unique mentioned accounts. screen_name is the
# number of matched unique accounts.

# %%
mention_join_df.count()
# Out:
# mention_screen_name          68235
# mention_screen_name_count    68235
# mention_screen_name_lower    68235
# screen_name                   2490
# user_id                       2490
# screen_name_lower             2490
# type                         68235
# dtype: int64

# %% [markdown]
# ### Top accounts by mentions
# NaN for screen_name indicates that it is not matched with an known Twitter account.

# %%
mention_join_df.sort_values('mention_screen_name_count', ascending=False).head(50)
# Out:
#       mention_screen_name  mention_screen_name_count  \
# 4569         BloombergBNA                       7055
# 61138     realDonaldTrump                       3367
# 4579         BloombergLaw                       2710
# 36690           WashBlade                       2300
# 19206     KimberlyRobinsn                       2254
# 23462      MorningConsult                       2221
# 12295       ForeignPolicy                       2144
# 26187               POTUS                       1916
# 10450                 EPA                       1847
# 31756               Slate                       1820
# 58984             nytimes                       1779
# 42006            business                       1562
# 43103           chronicle                       1431
# 865                    AP                       1386
# 67198      washingtonpost                       1360
# 2701       AnthonyAdragna                       1197
# 14580      HillaryClinton                       1163
# 9394           DefenseOne                        996
# 11630              FCWnow                        992
# 36479                 WSJ                        948
# 38410           agripulse                        880
# 24741          NatureNews                        868
# 27373            PressSec                        865
# 33679         TheAtlantic                        837
# 44574          daveweigel                        831
# 60345            politico                        826
# 16789       JeffreyToobin                        782
# 67266                 wcp                        780
# 65397             thehill                        776
# 51650            jmartNYT                        716
# 58102     nationaljournal                        687
# 3360      BBNAEnvironment                        650
# 67196       washingtonian                        650
# 1112          A_Childers_                        645
# 5876                  CNN                        631
# 12725           GOVERNING                        626
# 41546           bpolitics                        626
# 1795          Alex_Roarty                        606
# 235                 47abc                        601
# 55397           maggieNYT                        596
# 23802                NASA                        593
# 26424        Pat_Ambrosio                        581
# 24927           NewYorker                        577
# 25183          NinaEaston                        569
# 59430            palbergo                        568
# 36709           WashTimes                        561
# 28974             Reuters                        556
# 24985            Newsweek                        556
# 21594       MarcusReports                        555
# 4292            BigLawBiz                        545
#
#       mention_screen_name_lower      screen_name             user_id  \
# 4569               bloombergbna              NaN                 NaN
# 61138           realdonaldtrump  realDonaldTrump            25073877
# 4579               bloomberglaw              NaN                 NaN
# 36690                 washblade              NaN                 NaN
# 19206           kimberlyrobinsn  KimberlyRobinsn           906734342
# 23462            morningconsult              NaN                 NaN
# 12295             foreignpolicy              NaN                 NaN
# 26187                     potus            POTUS  822215679726100480
# 10450                       epa              EPA            14615871
# 31756                     slate              NaN                 NaN
# 58984                   nytimes          nytimes              807095
# 42006                  business              NaN                 NaN
# 43103                 chronicle              NaN                 NaN
# 865                          ap               AP            51241574
# 67198            washingtonpost   washingtonpost             2467791
# 2701             anthonyadragna   AnthonyAdragna           460246990
# 14580            hillaryclinton              NaN                 NaN
# 9394                 defenseone              NaN                 NaN
# 11630                    fcwnow              NaN                 NaN
# 36479                       wsj              WSJ             3108351
# 38410                 agripulse              NaN                 NaN
# 24741                naturenews              NaN                 NaN
# 27373                  presssec         PressSec  818927131883356161
# 33679               theatlantic              NaN                 NaN
# 44574                daveweigel       daveweigel            13524182
# 60345                  politico         politico             9300262
# 16789             jeffreytoobin    JeffreyToobin           522282462
# 67266                       wcp              wcp            14437161
# 65397                   thehill          thehill             1917731
# 51650                  jmartnyt         jmartNYT            18678924
# 58102           nationaljournal              NaN                 NaN
# 3360            bbnaenvironment              NaN                 NaN
# 67196             washingtonian              NaN                 NaN
# 1112                a_childers_      A_Childers_          1638925448
# 5876                        cnn              CNN              759251
# 12725                 governing              NaN                 NaN
# 41546                 bpolitics              NaN                 NaN
# 1795                alex_roarty              NaN                 NaN
# 235                       47abc            47abc           110771229
# 55397                 maggienyt              NaN                 NaN
# 23802                      nasa             NASA            11348282
# 26424              pat_ambrosio     Pat_Ambrosio          2497185313
# 24927                 newyorker              NaN                 NaN
# 25183                ninaeaston       NinaEaston            21270032
# 59430                  palbergo         palbergo           117467779
# 36709                 washtimes        WashTimes            14662354
# 28974                   reuters          Reuters             1652541
# 24985                  newsweek              NaN                 NaN
# 21594             marcusreports    MarcusReports           240737740
# 4292                  biglawbiz              NaN                 NaN
#
#       screen_name_lower         type
# 4569                NaN      unknown
# 61138   realdonaldtrump  politicians
# 4579                NaN      unknown
# 36690               NaN      unknown
# 19206   kimberlyrobinsn    reporters
# 23462               NaN      unknown
# 12295               NaN      unknown
# 26187             potus  politicians
# 10450               epa   government
# 31756               NaN      unknown
# 58984           nytimes        media
# 42006               NaN      unknown
# 43103               NaN      unknown
# 865                  ap        media
# 67198    washingtonpost        media
# 2701     anthonyadragna    reporters
# 14580               NaN      unknown
# 9394                NaN      unknown
# 11630               NaN      unknown
# 36479               wsj        media
# 38410               NaN      unknown
# 24741               NaN      unknown
# 27373          presssec  politicians
# 33679               NaN      unknown
# 44574        daveweigel    reporters
# 60345          politico        media
# 16789     jeffreytoobin    reporters
# 67266               wcp        media
# 65397           thehill        media
# 51650          jmartnyt    reporters
# 58102               NaN      unknown
# 3360                NaN      unknown
# 67196               NaN      unknown
# 1112        a_childers_    reporters
# 5876                cnn        media
# 12725               NaN      unknown
# 41546               NaN      unknown
# 1795                NaN      unknown
# 235               47abc        media
# 55397               NaN      unknown
# 23802              nasa   government
# 26424      pat_ambrosio    reporters
# 24927               NaN      unknown
# 25183        ninaeaston    reporters
# 59430          palbergo    reporters
# 36709         washtimes        media
# 28974           reuters        media
# 24985               NaN      unknown
# 21594     marcusreports    reporters
# 4292                NaN      unknown

# %% [markdown]
# ### Mentions by account type

# %%
mention_join_df.groupby('type').sum()
# Out:
#              mention_screen_name_count
# type
# government                       11548
# media                            19064
# politicians                      17713
# reporters                        50909
# unknown                         367532

# %% [markdown]
# ### Top (by mentions) accounts that are not known.
# These are the accounts that we will want to categorize.

# %%
mention_join_df[mention_join_df.type == 'unknown'].sort_values('mention_screen_name_count', ascending=False).head(50)
# Out:
#       mention_screen_name  mention_screen_name_count  \
# 4569         BloombergBNA                       7055
# 4579         BloombergLaw                       2710
# 36690           WashBlade                       2300
# 23462      MorningConsult                       2221
# 12295       ForeignPolicy                       2144
# 31756               Slate                       1820
# 42006            business                       1562
# 43103           chronicle                       1431
# 14580      HillaryClinton                       1163
# 9394           DefenseOne                        996
# 11630              FCWnow                        992
# 38410           agripulse                        880
# 24741          NatureNews                        868
# 33679         TheAtlantic                        837
# 58102     nationaljournal                        687
# 67196       washingtonian                        650
# 3360      BBNAEnvironment                        650
# 41546           bpolitics                        626
# 12725           GOVERNING                        626
# 1795          Alex_Roarty                        606
# 55397           maggieNYT                        596
# 24927           NewYorker                        577
# 24985            Newsweek                        556
# 4292            BigLawBiz                        545
# 24703           Nationals                        538
# 31959          SonnyBunch                        527
# 50374          jaketapper                        519
# 33840              TheFix                        509
# 67306      weeklystandard                        503
# 34491          TimAlberta                        468
# 14767         HotlineJosh                        462
# 2847            AriNatter                        458
# 11435          EthanolRFA                        456
# 67644               wmata                        453
# 31807          Smartwomen                        420
# 12557     FrontierStrtGrp                        416
# 60847        rachelpleven                        411
# 40822        benjaminpenn                        411
# 59871             pescami                        409
# 26949        Philanthropy                        404
# 22168        Matt_D_Cohen                        400
# 64209        stefanfatsis                        399
# 1158           AaronMehta                        397
# 24231                 NPR                        396
# 65005             tedcruz                        394
# 11541         ExaminerCom                        387
# 4363          BillKristol                        383
# 15977      JNicholsonInDC                        381
# 55558          marcorubio                        380
# 36450           WORLD_mag                        379
#
#       mention_screen_name_lower screen_name user_id screen_name_lower     type
# 4569               bloombergbna         NaN     NaN               NaN  unknown
# 4579               bloomberglaw         NaN     NaN               NaN  unknown
# 36690                 washblade         NaN     NaN               NaN  unknown
# 23462            morningconsult         NaN     NaN               NaN  unknown
# 12295             foreignpolicy         NaN     NaN               NaN  unknown
# 31756                     slate         NaN     NaN               NaN  unknown
# 42006                  business         NaN     NaN               NaN  unknown
# 43103                 chronicle         NaN     NaN               NaN  unknown
# 14580            hillaryclinton         NaN     NaN               NaN  unknown
# 9394                 defenseone         NaN     NaN               NaN  unknown
# 11630                    fcwnow         NaN     NaN               NaN  unknown
# 38410                 agripulse         NaN     NaN               NaN  unknown
# 24741                naturenews         NaN     NaN               NaN  unknown
# 33679               theatlantic         NaN     NaN               NaN  unknown
# 58102           nationaljournal         NaN     NaN               NaN  unknown
# 67196             washingtonian         NaN     NaN               NaN  unknown
# 3360            bbnaenvironment         NaN     NaN               NaN  unknown
# 41546                 bpolitics         NaN     NaN               NaN  unknown
# 12725                 governing         NaN     NaN               NaN  unknown
# 1795                alex_roarty         NaN     NaN               NaN  unknown
# 55397                 maggienyt         NaN     NaN               NaN  unknown
# 24927                 newyorker         NaN     NaN               NaN  unknown
# 24985                  newsweek         NaN     NaN               NaN  unknown
# 4292                  biglawbiz         NaN     NaN               NaN  unknown
# 24703                 nationals         NaN     NaN               NaN  unknown
# 31959                sonnybunch         NaN     NaN               NaN  unknown
# 50374                jaketapper         NaN     NaN               NaN  unknown
# 33840                    thefix         NaN     NaN               NaN  unknown
# 67306            weeklystandard         NaN     NaN               NaN  unknown
# 34491                timalberta         NaN     NaN               NaN  unknown
# 14767               hotlinejosh         NaN     NaN               NaN  unknown
# 2847                  arinatter         NaN     NaN               NaN  unknown
# 11435                ethanolrfa         NaN     NaN               NaN  unknown
# 67644                     wmata         NaN     NaN               NaN  unknown
# 31807                smartwomen         NaN     NaN               NaN  unknown
# 12557           frontierstrtgrp         NaN     NaN               NaN  unknown
# 60847              rachelpleven         NaN     NaN               NaN  unknown
# 40822              benjaminpenn         NaN     NaN               NaN  unknown
# 59871                   pescami         NaN     NaN               NaN  unknown
# 26949              philanthropy         NaN     NaN               NaN  unknown
# 22168              matt_d_cohen         NaN     NaN               NaN  unknown
# 64209              stefanfatsis         NaN     NaN               NaN  unknown
# 1158                 aaronmehta         NaN     NaN               NaN  unknown
# 24231                       npr         NaN     NaN               NaN  unknown
# 65005                   tedcruz         NaN     NaN               NaN  unknown
# 11541               examinercom         NaN     NaN               NaN  unknown
# 4363                billkristol         NaN     NaN               NaN  unknown
# 15977            jnicholsonindc         NaN     NaN               NaN  unknown
# 55558                marcorubio         NaN     NaN               NaN  unknown
# 36450                 world_mag         NaN     NaN               NaN  unknown
