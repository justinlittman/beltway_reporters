# %% [markdown]
# # Beltway reporters
#
# Goal here is:
# 1. Get a sense of the first tweets for each user.
# 2. Using mentions by the periodical reporters as an example, show that
#    these mentions can be categorized by comparing them against lists
#    of known Twitter accounts. For now, the rough categories
#    are government, media, politicians, and reporters but these can
#    be fixed later. This can then be replicated for other groups
#    (e.g., newspaper reporters), as well as retweets and replies.
# 3. Start putting together a list of additional Twitter accounts that need
#    to be categorized.

# %% [markdown]
# ## Setup
# This creates some functions used to load the data.

# %%
import pandas as pd
import numpy as np
import json
from dateutil.parser import parse as date_parse
import gzip
import logging

logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# Filepaths of the files to load.
filepaths = ['d59d27e2f2ed4778881573df2ecf2fad_001.json.gz',
            '25319652321b4bb498b250ffc53aa0f0_001.json.gz']

# Load tweets from gzipped, line-oriented JSON files, possibly transforming with provided function
# and limiting by number of tweets.
# Returns an iterator.
def tweet_iter(filepaths, limit=None, tweet_transform_func=None):
    for filepath in filepaths:
        with gzip.open(filepath) as file:
            for count, line in enumerate(file):
                if count % 50000 == 0:
                    logging.debug('Loaded %s', count)
                tweet = json.loads(line)
                if tweet_transform_func:
                    tweet_transform_ret = tweet_transform_func(tweet)
                    if isinstance(tweet_transform_ret, list):
                        for tweet in tweet_transform_ret:
                            yield tweet
                    else:
                        yield tweet_transform_ret
                else:
                    yield tweet
                if count+1 == limit:
                    break

# %% [markdown]
# ## Find first tweet for each user
# Note that by comparing the created_at date and the user_created_at date it can be determined which are new accounts and which are prolific tweeters.
#
# __Note that this is using data collected from the periodical press.__

# %% [markdown]
# ### Load the data and count.

# %%
# Simply the tweet on load
def tweet_transform(tweet):
    return { 
        'id': tweet['id_str'], 
        'created_at': date_parse(tweet['created_at']),
        'user_id': tweet['user']['id_str'],
        'screen_name': tweet['user']['screen_name'],
        'user_created_at': date_parse(tweet['user']['created_at']),
    }

tweet_df = pd.DataFrame(tweet_iter(filepaths, tweet_transform_func=tweet_transform))
tweet_df.count()
# Out:
# created_at         3364440
# id                 3364440
# screen_name        3364440
# user_created_at    3364440
# user_id            3364440
# dtype: int64

# %% [markdown]
# ### View the top of the data.

# %%
tweet_df.head()
# Out:
#                  created_at                  id  screen_name  \
# 0 2017-03-31 14:41:35+00:00  847821180832804864  A_Childers_
# 1 2017-03-31 14:15:34+00:00  847814632643473411  A_Childers_
# 2 2017-03-31 01:52:09+00:00  847627543142219776  A_Childers_
# 3 2017-03-30 23:52:23+00:00  847597404719267841  A_Childers_
# 4 2017-03-30 23:37:48+00:00  847593734896324608  A_Childers_
#
#             user_created_at     user_id
# 0 2013-08-01 21:44:28+00:00  1638925448
# 1 2013-08-01 21:44:28+00:00  1638925448
# 2 2013-08-01 21:44:28+00:00  1638925448
# 3 2013-08-01 21:44:28+00:00  1638925448
# 4 2013-08-01 21:44:28+00:00  1638925448

# %% [markdown]
# ### First tweet for each user
# created_at is the date of the first tweet in the dataset for the user. This can be compared
# against user_created_at, the date the user account was created.

# %%
tweet_df.loc[tweet_df.groupby('user_id')['created_at'].idxmin()].sort_values('created_at', ascending=False).head(20)
# Out:
#                        created_at                  id      screen_name  \
# 946753  2017-03-31 17:07:58+00:00  847858018809237504         sklee_ca
# 745318  2017-03-27 13:25:07+00:00  846352383609356288       emmaroller
# 959935  2017-03-17 17:27:58+00:00  842789621314588673  RebeccaEHoffman
# 942211  2017-03-15 14:16:31+00:00  842016664237559809    ErinMcManus15
# 2530157 2017-03-10 16:33:43+00:00  840239253745471489          EvanMcS
# 810658  2017-03-10 13:43:41+00:00  840196461472174081        CahnEmily
# 1906009 2017-03-08 20:33:21+00:00  839574782341414912   LaurenFCarroll
# 2552103 2017-03-07 16:38:59+00:00  839153415515168768       ericgeller
# 780962  2017-03-03 22:00:52+00:00  837784869958737920      HotlineJosh
# 2200367 2017-03-02 16:35:58+00:00  837340716560953344     chrisgeidner
# 27391   2017-02-28 19:00:31+00:00  836652316191244288   BeddingfieldMJ
# 1193879 2017-02-16 19:05:49+00:00  832304997639581698       AaronMehta
# 933507  2017-02-15 14:48:35+00:00  831877875762618368     AlexParkerDC
# 1823080 2017-02-12 15:54:14+00:00  830807232224833536    maria_e_recio
# 2113085 2017-02-09 21:56:58+00:00  829811353686831105       daveweigel
# 511794  2017-02-08 21:50:54+00:00  829447440034066432     OSHAReporter
# 3041588 2017-02-08 13:44:00+00:00  829324908438102016          sdonnan
# 15101   2017-02-03 20:46:05+00:00  827619189259194368     brianbeutler
# 297726  2017-02-03 01:33:02+00:00  827329014612291585        JSwiftTWS
# 1514745 2017-02-02 15:57:24+00:00  827184151430365184     ryanbeckwith
#
#                   user_created_at             user_id
# 946753  2009-09-23 17:09:53+00:00            76696176
# 745318  2009-08-18 19:10:55+00:00            66768858
# 959935  2017-03-17 17:18:52+00:00  842787331224584192
# 942211  2017-02-15 21:03:24+00:00  831972200014045191
# 2530157 2009-02-06 23:09:59+00:00            20281013
# 810658  2009-01-10 03:19:50+00:00            18825339
# 1906009 2009-04-10 06:29:32+00:00            30176025
# 2552103 2007-04-08 20:27:11+00:00             3817401
# 780962  2009-02-22 23:45:46+00:00            21612122
# 2200367 2009-03-05 06:48:00+00:00            22891564
# 27391   2017-02-28 18:23:37+00:00  836643030161625089
# 1193879 2010-01-08 15:53:25+00:00           103016675
# 933507  2011-03-31 20:53:10+00:00           275207082
# 1823080 2012-01-06 22:22:40+00:00           456994513
# 2113085 2008-02-15 17:58:23+00:00            13524182
# 511794  2017-02-03 19:50:14+00:00  827605131109793792
# 3041588 2009-02-24 23:10:17+00:00            21810329
# 15101   2009-02-23 21:31:16+00:00            21696279
# 297726  2008-06-17 15:19:03+00:00            15146659
# 1514745 2008-09-25 22:43:36+00:00            16459325

# %% [markdown]
# ## Top mentions
# Determine who is being mentioned and attempt to characterize.
#
# __Note that this is using data collected from the periodical press.__

# %%
# Simply the tweet on load
def mention_transform(tweet):
    mentions = []
    for mention in tweet.get('entities', {}).get('user_mentions', []):
        mentions.append({
            'id': tweet['id_str'],
            'user_id': tweet['user']['id_str'],
            'screen_name': tweet['user']['screen_name'],
            'mention_user_id': mention['id_str'],
            'mention_screen_name': mention['screen_name']
        })
    return mentions

mention_df = pd.DataFrame(tweet_iter(filepaths, tweet_transform_func=mention_transform))
# Out:
# DEBUG:root:Loaded 0
# DEBUG:root:Loaded 50000
# DEBUG:root:Loaded 100000
# DEBUG:root:Loaded 150000
# DEBUG:root:Loaded 200000
# DEBUG:root:Loaded 250000
# DEBUG:root:Loaded 300000
# DEBUG:root:Loaded 350000
# DEBUG:root:Loaded 400000
# DEBUG:root:Loaded 450000
# DEBUG:root:Loaded 500000
# DEBUG:root:Loaded 550000
# DEBUG:root:Loaded 600000
# DEBUG:root:Loaded 650000
# DEBUG:root:Loaded 700000
# DEBUG:root:Loaded 750000
# DEBUG:root:Loaded 800000
# DEBUG:root:Loaded 850000
# DEBUG:root:Loaded 900000
# DEBUG:root:Loaded 950000
# DEBUG:root:Loaded 1000000
# DEBUG:root:Loaded 1050000
# DEBUG:root:Loaded 1100000
# DEBUG:root:Loaded 1150000
# DEBUG:root:Loaded 1200000
# DEBUG:root:Loaded 1250000
# DEBUG:root:Loaded 1300000
# DEBUG:root:Loaded 1350000
# DEBUG:root:Loaded 1400000
# DEBUG:root:Loaded 1450000
# DEBUG:root:Loaded 1500000
# DEBUG:root:Loaded 0
# DEBUG:root:Loaded 50000
# DEBUG:root:Loaded 100000
# DEBUG:root:Loaded 150000
# DEBUG:root:Loaded 200000
# DEBUG:root:Loaded 250000
# DEBUG:root:Loaded 300000
# DEBUG:root:Loaded 350000
# DEBUG:root:Loaded 400000
# DEBUG:root:Loaded 450000
# DEBUG:root:Loaded 500000
# DEBUG:root:Loaded 550000
# DEBUG:root:Loaded 600000
# DEBUG:root:Loaded 650000
# DEBUG:root:Loaded 700000
# DEBUG:root:Loaded 750000
# DEBUG:root:Loaded 800000
# DEBUG:root:Loaded 850000
# DEBUG:root:Loaded 900000
# DEBUG:root:Loaded 950000
# DEBUG:root:Loaded 1000000
# DEBUG:root:Loaded 1050000
# DEBUG:root:Loaded 1100000
# DEBUG:root:Loaded 1150000
# DEBUG:root:Loaded 1200000
# DEBUG:root:Loaded 1250000
# DEBUG:root:Loaded 1300000
# DEBUG:root:Loaded 1350000
# DEBUG:root:Loaded 1400000
# DEBUG:root:Loaded 1450000
# DEBUG:root:Loaded 1500000
# DEBUG:root:Loaded 1550000
# DEBUG:root:Loaded 1600000
# DEBUG:root:Loaded 1650000
# DEBUG:root:Loaded 1700000
# DEBUG:root:Loaded 1750000
# DEBUG:root:Loaded 1800000

# %% [markdown]
# ### Number of mentions found in the dataset

# %%
mention_df.count()
# Out:
# id                     3029170
# mention_screen_name    3029170
# mention_user_id        3029170
# screen_name            3029170
# user_id                3029170
# dtype: int64

# %% [markdown]
# ### The mention data
# Each mention consists of the tweet id, the screen name and user id that is mentioned,
# and the screen_name and user_id that is mentioning.

# %%
mention_df.head()
# Out:
#                    id mention_screen_name mention_user_id  screen_name  \
# 0  847821180832804864          paulconndc        64502388  A_Childers_
# 1  847821180832804864        Pat_Ambrosio      2497185313  A_Childers_
# 2  847814632643473411              azevin        14744078  A_Childers_
# 3  847627543142219776       davidbschultz        53739928  A_Childers_
# 4  847597404719267841       davidbschultz        53739928  A_Childers_
#
#       user_id
# 0  1638925448
# 1  1638925448
# 2  1638925448
# 3  1638925448
# 4  1638925448

# %% [markdown]
# ### Top mentioned accounts

# %%
mention_summary_df = pd.DataFrame(mention_df.groupby('mention_screen_name').size().reset_index(name='mention_screen_name_count'))
mention_summary_df['mention_screen_name_lower'] = mention_summary_df.mention_screen_name.apply(str.lower)
mention_summary_df.sort_values('mention_screen_name_count', ascending=False).head(50)
# Out:
#        mention_screen_name  mention_screen_name_count  \
# 183261     realDonaldTrump                      33899
# 2674                    AP                      29688
# 17686                CQnow                      20586
# 108893                 WSJ                      18616
# 78501                POTUS                      16846
# 105905            USATODAY                      15634
# 43586       HillaryClinton                      15628
# 180900            politico                      15310
# 185611            rollcall                      15118
# 86343              Reuters                      14000
# 202137      washingtonpost                      12726
# 176901             nytimes                      12493
# 125458            business                      12370
# 138297       educationweek                      10667
# 13548         BloombergBNA                      10124
# 82109             PressSec                       9124
# 2804           AP_Politics                       9018
# 134090          dcexaminer                       8924
# 31198         EEPublishing                       7271
# 109507           WashTimes                       7070
# 165932           maggieNYT                       6848
# 196505             thehill                       6646
# 123990           bpolitics                       5839
# 13560         BloombergLaw                       5744
# 95366          SpeakerRyan                       5497
# 31424                  EPA                       5131
# 12282        BernieSanders                       4863
# 78477          POLITICOPro                       4840
# 133326          daveweigel                       4590
# 175675     nielslesniewski                       4366
# 62931            MEPFuller                       4214
# 14295          BostonGlobe                       4164
# 17434                  CNN                       4146
# 195336             tedcruz                       4114
# 112214         ZekeJMiller                       4049
# 80880         PhilipRucker                       3928
# 189428         seungminkim                       3896
# 125410           burgessev                       3823
# 14911         BresPolitico                       3814
# 108925         WSJPolitics                       3768
# 48652          JakeSherman                       3767
# 96806        StevenTDennis                       3745
# 31190        EENewsUpdates                       3707
# 11050          BarackObama                       3666
# 150895          jaketapper                       3646
# 39784          GlennThrush                       3508
# 2052                   AFP                       3472
# 174370     nationaljournal                       3416
# 107165                  VP                       3395
# 166529          marcorubio                       3366
#
#        mention_screen_name_lower
# 183261           realdonaldtrump
# 2674                          ap
# 17686                      cqnow
# 108893                       wsj
# 78501                      potus
# 105905                  usatoday
# 43586             hillaryclinton
# 180900                  politico
# 185611                  rollcall
# 86343                    reuters
# 202137            washingtonpost
# 176901                   nytimes
# 125458                  business
# 138297             educationweek
# 13548               bloombergbna
# 82109                   presssec
# 2804                 ap_politics
# 134090                dcexaminer
# 31198               eepublishing
# 109507                 washtimes
# 165932                 maggienyt
# 196505                   thehill
# 123990                 bpolitics
# 13560               bloomberglaw
# 95366                speakerryan
# 31424                        epa
# 12282              berniesanders
# 78477                politicopro
# 133326                daveweigel
# 175675           nielslesniewski
# 62931                  mepfuller
# 14295                bostonglobe
# 17434                        cnn
# 195336                   tedcruz
# 112214               zekejmiller
# 80880               philiprucker
# 189428               seungminkim
# 125410                 burgessev
# 14911               brespolitico
# 108925               wsjpolitics
# 48652                jakesherman
# 96806              steventdennis
# 31190              eenewsupdates
# 11050                barackobama
# 150895                jaketapper
# 39784                glennthrush
# 2052                         afp
# 174370           nationaljournal
# 107165                        vp
# 166529                marcorubio

# %% [markdown]
# ### Load known Twitter accounts

# %%
def seed_iter(filepath):
    with open(filepath) as file:
        for line in file:
            screen_name, user_id = line.split(',')
            yield {'screen_name': screen_name, 'user_id': user_id[:-1]}

def load_seed_df(filepath, seed_type):
    df = pd.DataFrame(seed_iter(filepath))
    df['screen_name_lower'] = df.screen_name.apply(str.lower)
    df['type'] = seed_type
    return df

# %%
federal_agencies_df = load_seed_df('federal_agencies.csv', 'government')
federal_agencies_df.count()
# Out:
# screen_name          2968
# user_id              2968
# screen_name_lower    2968
# type                 2968
# dtype: int64

# %%
news_outlets_df = load_seed_df('news_outlets.csv', 'media')
news_outlets_df.count()
# Out:
# screen_name          92
# user_id              92
# screen_name_lower    92
# type                 92
# dtype: int64

# %%
newspaper_reporters_df = load_seed_df('newspaper_reporters.csv', 'reporters')
newspaper_reporters_df.count()
# Out:
# screen_name          790
# user_id              790
# screen_name_lower    790
# type                 790
# dtype: int64

# %%
periodical_reporters_df = load_seed_df('periodical_reporters.csv', 'reporters')
periodical_reporters_df.count()
# Out:
# screen_name          677
# user_id              677
# screen_name_lower    677
# type                 677
# dtype: int64

# %%
administration_officials_df = load_seed_df('administration_officials.csv', 'politicians')
administration_officials_df.count()
# Out:
# screen_name          63
# user_id              63
# screen_name_lower    63
# type                 63
# dtype: int64

# %%
cabinet_df = load_seed_df('cabinet.csv', 'politicians')
cabinet_df.count()
# Out:
# screen_name          12
# user_id              12
# screen_name_lower    12
# type                 12
# dtype: int64

# %%
representatives_df = load_seed_df('representatives.csv', 'politicians')
representatives_df.count()
# Out:
# screen_name          431
# user_id              431
# screen_name_lower    431
# type                 431
# dtype: int64

# %%
senators_df = load_seed_df('senators.csv', 'politicians')
senators_df.count()
# Out:
# screen_name          100
# user_id              100
# screen_name_lower    100
# type                 100
# dtype: int64

# %%
media_df = load_seed_df('media.csv', 'media')
media_df.count()
# Out:
# screen_name          5997
# user_id              5997
# screen_name_lower    5997
# type                 5997
# dtype: int64

# %%
# Order is deliberate here, since will be deduplicating.
screen_name_lookup_df = newspaper_reporters_df.append([administration_officials_df,
                                      news_outlets_df,
                                      periodical_reporters_df,
                                      cabinet_df,
                                      representatives_df,
                                      senators_df,
                                      media_df,
                                      federal_agencies_df], ignore_index=True).drop_duplicates(subset='screen_name_lower')
screen_name_lookup_df.count()
# Out:
# screen_name          10932
# user_id              10932
# screen_name_lower    10932
# type                 10932
# dtype: int64

# %% [markdown]
# ### Join the mentions and the known Twitter accounts

# %%
mention_join_df = pd.merge(mention_summary_df, screen_name_lookup_df, how='left', left_on='mention_screen_name_lower', right_on='screen_name_lower')
mention_join_df['type'].fillna('unknown', inplace=True)

# %% [markdown]
# ### Top (by mention count) accounts that are matched against known Twitter accounts

# %%
mention_join_df[pd.notnull(mention_join_df.screen_name)].sort_values('mention_screen_name_count', ascending=False).head()
# Out:
#        mention_screen_name  mention_screen_name_count  \
# 183261     realDonaldTrump                      33899
# 2674                    AP                      29688
# 108893                 WSJ                      18616
# 78501                POTUS                      16846
# 105905            USATODAY                      15634
#
#        mention_screen_name_lower      screen_name             user_id  \
# 183261           realdonaldtrump  realDonaldTrump            25073877
# 2674                          ap               AP            51241574
# 108893                       wsj              WSJ             3108351
# 78501                      potus            POTUS  822215679726100480
# 105905                  usatoday         USATODAY            15754281
#
#        screen_name_lower         type
# 183261   realdonaldtrump  politicians
# 2674                  ap        media
# 108893               wsj        media
# 78501              potus  politicians
# 105905          usatoday        media

# %% [markdown]
# ### Number of matched accounts
# mention_screen_name is the number of unique mentioned accounts. screen_name is the
# number of matched unique accounts.

# %%
mention_join_df.count()
# Out:
# mention_screen_name          205243
# mention_screen_name_count    205243
# mention_screen_name_lower    205243
# screen_name                    4445
# user_id                        4445
# screen_name_lower              4445
# type                         205243
# dtype: int64

# %% [markdown]
# ### Top accounts by mentions
# NaN for screen_name indicates that it is not matched with an known Twitter account.

# %%
mention_join_df.sort_values('mention_screen_name_count', ascending=False).head(50)
# Out:
#        mention_screen_name  mention_screen_name_count  \
# 183261     realDonaldTrump                      33899
# 2674                    AP                      29688
# 17686                CQnow                      20586
# 108893                 WSJ                      18616
# 78501                POTUS                      16846
# 105905            USATODAY                      15634
# 43586       HillaryClinton                      15628
# 180900            politico                      15310
# 185611            rollcall                      15118
# 86343              Reuters                      14000
# 202137      washingtonpost                      12726
# 176901             nytimes                      12493
# 125458            business                      12370
# 138297       educationweek                      10667
# 13548         BloombergBNA                      10124
# 82109             PressSec                       9124
# 2804           AP_Politics                       9018
# 134090          dcexaminer                       8924
# 31198         EEPublishing                       7271
# 109507           WashTimes                       7070
# 165932           maggieNYT                       6848
# 196505             thehill                       6646
# 123990           bpolitics                       5839
# 13560         BloombergLaw                       5744
# 95366          SpeakerRyan                       5497
# 31424                  EPA                       5131
# 12282        BernieSanders                       4863
# 78477          POLITICOPro                       4840
# 133326          daveweigel                       4590
# 175675     nielslesniewski                       4366
# 62931            MEPFuller                       4214
# 14295          BostonGlobe                       4164
# 17434                  CNN                       4146
# 195336             tedcruz                       4114
# 112214         ZekeJMiller                       4049
# 80880         PhilipRucker                       3928
# 189428         seungminkim                       3896
# 125410           burgessev                       3823
# 14911         BresPolitico                       3814
# 108925         WSJPolitics                       3768
# 48652          JakeSherman                       3767
# 96806        StevenTDennis                       3745
# 31190        EENewsUpdates                       3707
# 11050          BarackObama                       3666
# 150895          jaketapper                       3646
# 39784          GlennThrush                       3508
# 2052                   AFP                       3472
# 174370     nationaljournal                       3416
# 107165                  VP                       3395
# 166529          marcorubio                       3366
#
#        mention_screen_name_lower      screen_name             user_id  \
# 183261           realdonaldtrump  realDonaldTrump            25073877
# 2674                          ap               AP            51241574
# 17686                      cqnow              NaN                 NaN
# 108893                       wsj              WSJ             3108351
# 78501                      potus            POTUS  822215679726100480
# 105905                  usatoday         USATODAY            15754281
# 43586             hillaryclinton              NaN                 NaN
# 180900                  politico         politico             9300262
# 185611                  rollcall         rollcall            15922214
# 86343                    reuters          Reuters             1652541
# 202137            washingtonpost   washingtonpost             2467791
# 176901                   nytimes          nytimes              807095
# 125458                  business              NaN                 NaN
# 138297             educationweek              NaN                 NaN
# 13548               bloombergbna              NaN                 NaN
# 82109                   presssec         PressSec  818927131883356161
# 2804                 ap_politics      AP_Politics           426802833
# 134090                dcexaminer              NaN                 NaN
# 31198               eepublishing              NaN                 NaN
# 109507                 washtimes        WashTimes            14662354
# 165932                 maggienyt              NaN                 NaN
# 196505                   thehill          thehill             1917731
# 123990                 bpolitics              NaN                 NaN
# 13560               bloomberglaw              NaN                 NaN
# 95366                speakerryan      SpeakerRyan            18916432
# 31424                        epa              EPA            14615871
# 12282              berniesanders              NaN                 NaN
# 78477                politicopro              NaN                 NaN
# 133326                daveweigel       daveweigel            13524182
# 175675           nielslesniewski  nielslesniewski           140286364
# 62931                  mepfuller        MEPFuller           398088661
# 14295                bostonglobe      BostonGlobe            95431448
# 17434                        cnn              CNN              759251
# 195336                   tedcruz              NaN                 NaN
# 112214               zekejmiller      ZekeJMiller            21316253
# 80880               philiprucker              NaN                 NaN
# 189428               seungminkim      seungminkim            19186003
# 125410                 burgessev        burgessev           407013776
# 14911               brespolitico     BresPolitico           217550862
# 108925               wsjpolitics              NaN                 NaN
# 48652                jakesherman      JakeSherman            21252618
# 96806              steventdennis    StevenTDennis            46557945
# 31190              eenewsupdates              NaN                 NaN
# 11050                barackobama              NaN                 NaN
# 150895                jaketapper              NaN                 NaN
# 39784                glennthrush      GlennThrush            19107878
# 2052                         afp              AFP           380648579
# 174370           nationaljournal              NaN                 NaN
# 107165                        vp               VP  818910970567344128
# 166529                marcorubio              NaN                 NaN
#
#        screen_name_lower         type
# 183261   realdonaldtrump  politicians
# 2674                  ap        media
# 17686                NaN      unknown
# 108893               wsj        media
# 78501              potus  politicians
# 105905          usatoday        media
# 43586                NaN      unknown
# 180900          politico        media
# 185611          rollcall        media
# 86343            reuters        media
# 202137    washingtonpost        media
# 176901           nytimes        media
# 125458               NaN      unknown
# 138297               NaN      unknown
# 13548                NaN      unknown
# 82109           presssec  politicians
# 2804         ap_politics        media
# 134090               NaN      unknown
# 31198                NaN      unknown
# 109507         washtimes        media
# 165932               NaN      unknown
# 196505           thehill        media
# 123990               NaN      unknown
# 13560                NaN      unknown
# 95366        speakerryan  politicians
# 31424                epa   government
# 12282                NaN      unknown
# 78477                NaN      unknown
# 133326        daveweigel    reporters
# 175675   nielslesniewski    reporters
# 62931          mepfuller    reporters
# 14295        bostonglobe        media
# 17434                cnn        media
# 195336               NaN      unknown
# 112214       zekejmiller    reporters
# 80880                NaN      unknown
# 189428       seungminkim    reporters
# 125410         burgessev    reporters
# 14911       brespolitico    reporters
# 108925               NaN      unknown
# 48652        jakesherman    reporters
# 96806      steventdennis    reporters
# 31190                NaN      unknown
# 11050                NaN      unknown
# 150895               NaN      unknown
# 39784        glennthrush    reporters
# 2052                 afp        media
# 174370               NaN      unknown
# 107165                vp  politicians
# 166529               NaN      unknown

# %% [markdown]
# ### Mentions by account type

# %%
mention_join_df.groupby('type').sum()
# Out:
#              mention_screen_name_count
# type
# government                       61099
# media                           236317
# politicians                     164298
# reporters                       563052
# unknown                        2004404

# %% [markdown]
# ### Top (by mentions) accounts that are not known.
# These are the accounts that we will want to categorize.

# %%
mention_join_df[mention_join_df.type == 'unknown'].sort_values('mention_screen_name_count', ascending=False).head(50)
# Out:
#        mention_screen_name  mention_screen_name_count  \
# 17686                CQnow                      20586
# 43586       HillaryClinton                      15628
# 125458            business                      12370
# 138297       educationweek                      10667
# 13548         BloombergBNA                      10124
# 134090          dcexaminer                       8924
# 31198         EEPublishing                       7271
# 165932           maggieNYT                       6848
# 123990           bpolitics                       5839
# 13560         BloombergLaw                       5744
# 12282        BernieSanders                       4863
# 78477          POLITICOPro                       4840
# 195336             tedcruz                       4114
# 80880         PhilipRucker                       3928
# 108925         WSJPolitics                       3768
# 31190        EENewsUpdates                       3707
# 11050          BarackObama                       3666
# 150895          jaketapper                       3646
# 174370     nationaljournal                       3416
# 166529          marcorubio                       3366
# 34935             FERNnews                       3316
# 94474                Slate                       3290
# 35271                   FT                       3207
# 70657       MorningConsult                       3177
# 83590                  RNS                       3157
# 82728              Publici                       3051
# 175082          newsfromIN                       2985
# 69500       Militarydotcom                       2938
# 123071      blakehounshell                       2853
# 74988              Nextgov                       2809
# 130844        costareports                       2780
# 36800        ForeignPolicy                       2674
# 81632          PoliticsK12                       2667
# 81563           PolitiFact                       2601
# 72860                  NPR                       2586
# 100964              TheFix                       2468
# 14529           BraddJaffy                       2453
# 100507         TheAtlantic                       2418
# 109473           WashBlade                       2388
# 95094             SopanDeb                       2370
# 161676            ktumulty                       2317
# 131494               cspan                       2302
# 124659        brianstelter                       2270
# 80832       Phil_Mattingly                       2240
# 134249            ddiamond                       2223
# 98426                 TIME                       2217
# 92878          SenatorReid                       2138
# 10587                   BV                       2118
# 183760         reidepstein                       2094
# 167066         markknoller                       2082
#
#        mention_screen_name_lower screen_name user_id screen_name_lower  \
# 17686                      cqnow         NaN     NaN               NaN
# 43586             hillaryclinton         NaN     NaN               NaN
# 125458                  business         NaN     NaN               NaN
# 138297             educationweek         NaN     NaN               NaN
# 13548               bloombergbna         NaN     NaN               NaN
# 134090                dcexaminer         NaN     NaN               NaN
# 31198               eepublishing         NaN     NaN               NaN
# 165932                 maggienyt         NaN     NaN               NaN
# 123990                 bpolitics         NaN     NaN               NaN
# 13560               bloomberglaw         NaN     NaN               NaN
# 12282              berniesanders         NaN     NaN               NaN
# 78477                politicopro         NaN     NaN               NaN
# 195336                   tedcruz         NaN     NaN               NaN
# 80880               philiprucker         NaN     NaN               NaN
# 108925               wsjpolitics         NaN     NaN               NaN
# 31190              eenewsupdates         NaN     NaN               NaN
# 11050                barackobama         NaN     NaN               NaN
# 150895                jaketapper         NaN     NaN               NaN
# 174370           nationaljournal         NaN     NaN               NaN
# 166529                marcorubio         NaN     NaN               NaN
# 34935                   fernnews         NaN     NaN               NaN
# 94474                      slate         NaN     NaN               NaN
# 35271                         ft         NaN     NaN               NaN
# 70657             morningconsult         NaN     NaN               NaN
# 83590                        rns         NaN     NaN               NaN
# 82728                    publici         NaN     NaN               NaN
# 175082                newsfromin         NaN     NaN               NaN
# 69500             militarydotcom         NaN     NaN               NaN
# 123071            blakehounshell         NaN     NaN               NaN
# 74988                    nextgov         NaN     NaN               NaN
# 130844              costareports         NaN     NaN               NaN
# 36800              foreignpolicy         NaN     NaN               NaN
# 81632                politicsk12         NaN     NaN               NaN
# 81563                 politifact         NaN     NaN               NaN
# 72860                        npr         NaN     NaN               NaN
# 100964                    thefix         NaN     NaN               NaN
# 14529                 braddjaffy         NaN     NaN               NaN
# 100507               theatlantic         NaN     NaN               NaN
# 109473                 washblade         NaN     NaN               NaN
# 95094                   sopandeb         NaN     NaN               NaN
# 161676                  ktumulty         NaN     NaN               NaN
# 131494                     cspan         NaN     NaN               NaN
# 124659              brianstelter         NaN     NaN               NaN
# 80832             phil_mattingly         NaN     NaN               NaN
# 134249                  ddiamond         NaN     NaN               NaN
# 98426                       time         NaN     NaN               NaN
# 92878                senatorreid         NaN     NaN               NaN
# 10587                         bv         NaN     NaN               NaN
# 183760               reidepstein         NaN     NaN               NaN
# 167066               markknoller         NaN     NaN               NaN
#
#            type
# 17686   unknown
# 43586   unknown
# 125458  unknown
# 138297  unknown
# 13548   unknown
# 134090  unknown
# 31198   unknown
# 165932  unknown
# 123990  unknown
# 13560   unknown
# 12282   unknown
# 78477   unknown
# 195336  unknown
# 80880   unknown
# 108925  unknown
# 31190   unknown
# 11050   unknown
# 150895  unknown
# 174370  unknown
# 166529  unknown
# 34935   unknown
# 94474   unknown
# 35271   unknown
# 70657   unknown
# 83590   unknown
# 82728   unknown
# 175082  unknown
# 69500   unknown
# 123071  unknown
# 74988   unknown
# 130844  unknown
# 36800   unknown
# 81632   unknown
# 81563   unknown
# 72860   unknown
# 100964  unknown
# 14529   unknown
# 100507  unknown
# 109473  unknown
# 95094   unknown
# 161676  unknown
# 131494  unknown
# 124659  unknown
# 80832   unknown
# 134249  unknown
# 98426   unknown
# 92878   unknown
# 10587   unknown
# 183760  unknown
# 167066  unknown
